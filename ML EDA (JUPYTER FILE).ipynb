# %%
import pandas as pd

# %%
d=pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
d.head(5)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=d['Sleep Duration'])
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='count'>

# %% [markdown]
# Majority of the people sleeps for 7.2 hours

# %%
sns.countplot(x=d['Quality of Sleep'])
# Out:
# <Axes: xlabel='Quality of Sleep', ylabel='count'>

# %%
sns.countplot(x=d['Physical Activity Level'])
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='count'>

# %%
sns.countplot(x=d['Stress Level'])
# Out:
# <Axes: xlabel='Stress Level', ylabel='count'>

# %%
plt.hist(d['Daily Steps'], bins=150)
plt.xlabel('Daily steps')
plt.ylabel("count")
plt.show()
plt.figure(figsize=(50,100))

# %% [markdown]
# Most people have a step count of 8000

# %%
sns.countplot(x=d['Sleep Disorder'])
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
d[(d['Sleep Disorder']=='Sleep Apnea') | (d['Sleep Disorder']== 'Insomnia')]['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   64
# Teacher                 31
# Salesperson             30
# Doctor                   7
# Accountant               7
# Engineer                 6
# Lawyer                   5
# Sales Representative     2
# Scientist                2
# Software Engineer        1
# Name: count, dtype: int64

# %% [markdown]
# Nurses have the major problem of Sleep Disorder
